# %%
# !pip install python-dotenv langchain langchain-core langchain-community langchain-google-genai chromadb langchain-text-splitters beautifulsoup4 sentence-transformers einops langchainhub langsmith faiss-cpu pydantic rank_bm25 sentence-transformers
# Out:
# Requirement already satisfied: python-dotenv in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (1.2.2)
# Requirement already satisfied: langchain in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (1.2.11)
# Requirement already satisfied: langchain-core in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (1.2.18)
# Requirement already satisfied: langchain-community in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (0.4.1)
# Requirement already satisfied: langchain-google-genai in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (4.2.1)
# Requirement already satisfied: chromadb in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (1.5.5)
# Requirement already satisfied: langchain-text-splitters in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (1.1.1)
# Requirement already satisfied: beautifulsoup4 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (4.14.3)
# Requirement already satisfied: sentence-transformers in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (5.2.3)
# Requirement already satisfied: einops in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (0.8.2)
# Requirement already satisfied: langchainhub in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (0.1.21)
# Requirement already satisfied: langsmith in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (0.7.16)
# Requirement already satisfied: faiss-cpu in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (1.13.2)
# Requirement already satisfied: pydantic in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (2.12.5)
# Requirement already satisfied: rank_bm25 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (0.2.2)
# Requirement already satisfied: langgraph<1.3.0,>=1.1.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from langchain) (1.1.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from langchain-core) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from langchain-core) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from langchain-core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from langchain-core) (4.14.1)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from langchain-core) (0.14.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from langsmith) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from langsmith) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from langsmith) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from langsmith) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from langsmith) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from langsmith) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from pydantic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: anyio in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith) (4.12.1)
# Requirement already satisfied: certifi in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith) (1.0.9)
# Requirement already satisfied: idna in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith) (3.10)
# Requirement already satisfied: h11>=0.16 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from langgraph<1.3.0,>=1.1.0->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from langgraph<1.3.0,>=1.1.0->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from langgraph<1.3.0,>=1.1.0->langchain) (0.3.11)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.3.0,>=1.1.0->langchain) (1.12.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from langchain-community) (1.0.2)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from langchain-community) (2.0.48)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from langchain-community) (2.2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from requests>=2.0.0->langsmith) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from requests>=2.0.0->langsmith) (2.5.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.56.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from langchain-google-genai) (1.66.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.47.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2.49.0)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (46.0.5)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.6.2)
# Requirement already satisfied: build>=1.0.3 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from chromadb) (1.4.0)
# Requirement already satisfied: pybase64>=1.4.1 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.41.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from chromadb) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from chromadb) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from chromadb) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from chromadb) (1.78.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from chromadb) (0.24.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: rich>=10.11.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from chromadb) (14.3.3)
# Requirement already satisfied: jsonschema>=4.19.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from beautifulsoup4) (2.8.3)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from sentence-transformers) (5.3.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from sentence-transformers) (1.6.0)
# Requirement already satisfied: torch>=1.11.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from sentence-transformers) (2.10.0)
# Requirement already satisfied: scikit-learn in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.2.28)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.25.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.3.2)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from langchainhub) (2.32.4.20260107)
# Requirement already satisfied: pyproject_hooks in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: importlib-metadata>=4.6 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (8.7.1)
# Requirement already satisfied: tomli>=1.1.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (2.4.0)
# Requirement already satisfied: cffi>=2.0.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2.0.0)
# Requirement already satisfied: pycparser in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (3.0)
# Requirement already satisfied: zipp>=3.20 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from importlib-metadata>=4.6->build>=1.0.3->chromadb) (3.23.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: coloredlogs in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.5)
# Requirement already satisfied: sympy in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.73.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.40.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-proto==1.40.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.61b0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.61b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: networkx>=2.5.1 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: click>=8.2.1 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/anideepkalia/Documents/ML-tut/venv/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (3.6.0)

# %% [markdown]
# ## Declaration

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.documents import Document
from langchain_core.output_parsers import JsonOutputParser
from langchain_google_genai import ChatGoogleGenerativeAI
import json
import numpy as np
import os
import warnings
from dotenv import load_dotenv
from pydantic import BaseModel
from typing import List
from langchain_community.retrievers import BM25Retriever
from langgraph.graph import StateGraph, END
from pydantic import BaseModel
from typing import TypedDict, List
from sentence_transformers import CrossEncoder
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import Chroma


load_dotenv()
os.environ["GOOGLE_API_KEY"] = "AIzaSyBpyIDcNa7SfhMFGEKDNrdxLMoz2DtrBrQ"
os.environ["LANGCHAIN_API_KEY"] = "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"
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_ENDPOINT"] = "https://api.smith.langchain.com"
warnings.filterwarnings("ignore")



class QueryOutput(BaseModel):
    rewritten_query: str
    expanded_queries: List[str]
    step_back_query: str

class QueryOptimizerOutput(BaseModel):
    rewritten_query: str
    expanded_queries: List[str]
    step_back_query: str

class GraphState(TypedDict):
    query: str
    rewritten_query: str
    expanded_queries: List[str]
    step_back_query: str
    documents: List[Document]
    answer: str
    iteration: int
    retrieval_feedback: dict
    doc_scores: List[float]

llm = ChatGoogleGenerativeAI(model="gemini-3-flash-preview")
structured_llm = llm.with_structured_output(QueryOutput)
cross_encoder = CrossEncoder("cross-encoder/ms-marco-MiniLM-L-6-v2")
# Out:
# Loading weights: 100%|██████████| 105/105 [00:00<00:00, 7792.10it/s]
# BertForSequenceClassification LOAD REPORT from: cross-encoder/ms-marco-MiniLM-L-6-v2
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# bert.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %% [markdown]
# ## Query Rewritting & Expansion
#
# * User Query  ->  Query Rewriting  ->  Step-Back Query  ->  Query Expansion
#
#
# | Step      | Why                                      |
# | --------- | ---------------------------------------- |
# | Rewrite   | cleans the query and removes ambiguity   |
# | Step-back | captures **higher-level concept**        |
# | Expansion | generates **multiple search variations** |

# %%
optimizer_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are an expert query optimizer. Return ONLY JSON."),
    ("human", """
        User Query:
        {query}

        Perform:
        1. Rewrite query
        2. Generate 6 variations
        3. Generate step-back query

        Return JSON:

        {{
        "rewritten_query": "...",
        "expanded_queries": ["...", "...", "...", "..."],
        "step_back_query": "..."
        }}
    """)
])

def query_intelligence_node(state):

    iteration = state.get("iteration", 0)

    # PASS 1 (normal)
    if iteration == 0:
        query = state["query"]

        prompt = optimizer_prompt.invoke({
            "query": query
        })

    # PASS 2 (feedback-driven)
    else:
        feedback = state.get("retrieval_feedback", {})

        snippets = [
            doc.page_content[:200] 
            for doc in state.get("documents", [])[:2]
        ]

        refined_query = f"""
            Previous retrieval failed.

            Reason: {feedback.get("reason")}
            Max Score: {feedback.get("max_score")}
            Avg Score: {feedback.get("avg_score")}

            The following snippets were retrieved but are NOT relevant:
            {chr(10).join(snippets)}

            IMPORTANT:
            - These snippets are incorrect or irrelevant
            - Do NOT base your query on them
            - Use them only to understand what went wrong

            Original Query:
            {state["query"]}

            Previous Rewritten Query:
            {state.get("rewritten_query")}

            Your task:
            - Identify why retrieval failed
            - Fix the query without drifting away from user intent
            - Preserve original intent strictly
            - Improve specificity and keywords
        """
        
        prompt = optimizer_prompt.invoke({
            "query": refined_query
        })

    result = structured_llm.invoke(prompt)

    print("Rewritten_query",result.rewritten_query)
    print("Expanded_queries",result.expanded_queries)
    print("Step_back_query",result.step_back_query)

    return {
        "rewritten_query": result.rewritten_query,
        "expanded_queries": result.expanded_queries,
        "step_back_query": result.step_back_query
    }

# %% [markdown]
# VECTOR-DB, EMBEDDINGS & INGESTION

# %%
embeddings = HuggingFaceEmbeddings(model_name="nomic-ai/nomic-embed-text-v1",model_kwargs={"trust_remote_code": True})

documents = [
    Document(page_content="RAG systems retrieve documents before generation."),
    Document(page_content="Faithfulness measures whether answers are grounded in retrieved documents."),
    Document(page_content="Query expansion improves recall in retrieval systems."),
]

vectorstore = Chroma.from_documents(
    documents=documents,
    collection_name="verirag-chroma",
    embedding=embeddings,
)

vector_retriever = vectorstore.as_retriever(search_kwargs={"k": 5})
bm25_retriever = BM25Retriever.from_documents(documents)
bm25_retriever.k = 5
# Out:
# <All keys matched successfully>

# %% [markdown]
# RETRIEVER

# %%
# Retrieve top 5 results from both BM25 and Vector retrievers, then deduplicate results
def hybrid_retrieve_node(state):
    queries = (
        [state["rewritten_query"]] +
        state["expanded_queries"] +
        [state["step_back_query"]]
    )

    all_docs = []
    print("----------------------------")
    for q in queries:
        print("Query: ",q)
        all_docs.extend(bm25_retriever.invoke(q))
        all_docs.extend(vector_retriever.invoke(q))
        print(all_docs)
        
    print("----------------------------")
    # Deduplicate
    unique_docs = list({doc.page_content: doc for doc in all_docs}.values())

    return {"documents": unique_docs}

# %% [markdown]
# ## Cross Encoder & Re-Ranking

# %%
# Rerank retrieved documents using cross-encoder, normalised scores and filter out low-relevance docs based on a threshold
def rerank_and_filter_node(state):

    docs = state.get("documents", [])
    query = state["query"]

    if not docs:
        return {
            "documents": [],
            "answer": "I don't know",
            "retrieval_feedback": {"reason": "no_docs"}
        }

    pairs = [(query, doc.page_content) for doc in docs]
    scores = cross_encoder.predict(pairs)
    scores = 1 / (1 + np.exp(-scores))

    doc_scores = list(zip(docs, scores))
    doc_scores.sort(key=lambda x: x[1], reverse=True)

    top_docs = doc_scores[:5]
    top_scores = [score for _, score in top_docs]
    print(top_scores)
    print("----------------------------")
    max_score = max(top_scores)
    avg_score = sum(top_scores) / len(top_scores)

    threshold = 0.6

    if max_score < threshold:
        return {
            "documents": [doc for doc, _ in top_docs],
            "doc_scores": top_scores,
            "retrieval_feedback": {
                "reason": "low_relevance",
                "max_score": float(max_score),
                "avg_score": float(avg_score)
            }
        }

    return {
        "documents": [doc for doc, _ in top_docs],
        "doc_scores": top_scores
    }

# %%
def Retry_decision_logic(state):

    iteration = state.get("iteration", 0)
    max_iterations = 2

    if state.get("answer") == "I don't know" and iteration >= max_iterations:
        return "generate"

    # If no docs → retry
    if not state.get("documents") and iteration < max_iterations:
        return "retry"

    return "generate"

def Refine_query_node(state):
    return {
        "iteration": state.get("iteration", 0) + 1
    }

# %% [markdown]
# ## GENERATION

# %%
generation_prompt = ChatPromptTemplate.from_template(
"""
You are a strict assistant.

Answer ONLY using the provided context.
If the answer is not clearly present, say "I don't know".

Question:
{query}

Context:
{context}

Answer:
"""
)

def generate_answer_node(state):

    # If reranker already decided to stop
    if state.get("answer") == "I don't know":
        return {"answer": "I don't know"}

    docs = state.get("documents", [])

    if not docs:
        return {"answer": "I don't know"}

    context = "\n\n".join([doc.page_content for doc in docs])

    prompt = generation_prompt.format(
        query=state["query"],
        context=context
    )

    response = llm.invoke(prompt)

    return {"answer": response.content}

# %% [markdown]
# ## Graph Compliation

# %%
builder = StateGraph(GraphState)

builder.add_node("query_intelligence", query_intelligence_node)
builder.add_node("hybrid_retrieve", hybrid_retrieve_node)
builder.add_node("rerank", rerank_and_filter_node)
builder.add_node("Refine_query", Refine_query_node)
builder.add_node("generate", generate_answer_node)

builder.set_entry_point("query_intelligence")

builder.add_edge("query_intelligence", "hybrid_retrieve")
builder.add_edge("hybrid_retrieve", "rerank")


builder.add_conditional_edges(
    "rerank",
    Retry_decision_logic,
    {
        "retry": "Refine_query",
        "generate": "generate"
    }
)

builder.add_edge("Refine_query", "query_intelligence")
builder.add_edge("generate", END)

graph = builder.compile()

from IPython.display import Image, display # type: ignore
display(Image(graph.get_graph(xray=True).draw_mermaid_png()))

# %% [markdown]
# ## Inferencing RAG

# %%
result = graph.invoke({
    # "query": "How do we measure faithfulness in computer terminal?"
    "query": "How do we measure faithfulness in RAG?",
    "iteration": 0
})
print(result["answer"])
# Out:
# Rewritten_query What are the standard metrics and methodologies used to quantify faithfulness and groundedness in Retrieval-Augmented Generation (RAG) pipelines?
# Expanded_queries ['How does the RAGAS framework define and calculate the faithfulness score?', 'Comparison of faithfulness evaluation tools like TruLens, RAGAS, and Arize Phoenix', 'Using Natural Language Inference (NLI) to detect hallucinations in RAG outputs', 'What is the mathematical formula for measuring faithfulness in context-aware generation?', 'How to evaluate if an LLM response is strictly derived from retrieved documents', 'Best practices for automated evaluation of groundedness in AI search systems']
# Step_back_query What are the fundamental principles and criteria for evaluating the quality of Retrieval-Augmented Generation systems?
# ----------------------------
# Query:  What are the standard metrics and methodologies used to quantify faithfulness and groundedness in Retrieval-Augmented Generation (RAG) pipelines?
# [Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.')]
# Query:  How does the RAGAS framework define and calculate the faithfulness score?
# [Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.')]
# Query:  Comparison of faithfulness evaluation tools like TruLens, RAGAS, and Arize Phoenix
# [Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.')]
# Query:  Using Natural Language Inference (NLI) to detect hallucinations in RAG outputs
# [Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.')]
# Query:  What is the mathematical formula for measuring faithfulness in context-aware generation?
# [Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before g ...
# Query:  How to evaluate if an LLM response is strictly derived from retrieved documents
# [Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before g ...
# Query:  Best practices for automated evaluation of groundedness in AI search systems
# [Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before g ...
# Query:  What are the fundamental principles and criteria for evaluating the quality of Retrieval-Augmented Generation systems?
# [Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Query expansion improves recall in retrieval systems.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='Faithfulness measures whether answers are grounded in retrieved documents.'), Document(metadata={}, page_content='RAG systems retrieve documents before generation.'), Document(metadata={}, page_content='RAG systems retrieve documents before g ...
# ----------------------------
# [np.float32(0.67226183), np.float32(0.00014689895), np.float32(1.0431016e-05)]
# ----------------------------
# [{'type': 'text', 'text': 'Faithfulness measures whether answers are grounded in retrieved documents.', 'extras': {'signature': '...'}}]
